# %%
# !git clone https://github.com/nianticlabs/monodepth2.git
# %cd monodepth2
# Out:
# Cloning into 'monodepth2'...
# remote: Enumerating objects: 180, done.
# remote: Total 180 (delta 0), reused 0 (delta 0), pack-reused 180 (from 1)
# Receiving objects: 100% (180/180), 10.27 MiB | 30.30 MiB/s, done.
# Resolving deltas: 100% (89/89), done.
# /content/monodepth2

# %%
# !pip install torch torchvision
# !pip install tensorboardX
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 40.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !python test_simple.py --image_path assets/test_image.jpg --model_name mono+stereo_640x192
# Out:
# -> Downloading pretrained model to models/mono+stereo_640x192.zip
#    Unzipping model...
#    Model unzipped to models/mono+stereo_640x192
# -> Loading model from  models/mono+stereo_640x192
#    Loading pretrained encoder
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ...

# %%
from IPython.display import display
from PIL import Image

# Load and display the predicted depth map
depth_image = Image.open("assets/test_image_disp.jpeg")
display(depth_image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=638x235>

# %%
#use the model to generate the depth map
# !python test_simple.py --image_path assets/original.jpg --model_name mono+stereo_640x192
# Out:
# -> Loading model from  models/mono+stereo_640x192
#    Loading pretrained encoder
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ...

# %%
#show the depth map which just generated
depth_image = Image.open("assets/original_disp.jpeg")
display(depth_image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1242x375>

# %%
#use the model to generate another depth map for realistic snow image based on former image
# !python test_simple.py --image_path assets/realistic_snow01.jpg --model_name mono+stereo_640x192
# Out:
# -> Loading model from  models/mono+stereo_640x192
#    Loading pretrained encoder
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ...

# %%
#show the depth map for realistic snow image
depth_image = Image.open("assets/realistic_snow01_disp.jpeg")
display(depth_image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1240x368>
